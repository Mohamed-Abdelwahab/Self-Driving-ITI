# %% [markdown]
# # Corner Dtection
#
# - Understand and Explore `Harris` corner detection.
# - Using OpenCV, apply it to all images in Chess folder.
#
# ## Criteria
#
# - Detect as much chessboard corners as you can in all images.
#
# ## Grade
# - 12

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import time
# %matplotlib inline

# %%
# Read in the images
image1 = cv2.imread('Files/Chess/001.png')
image2 = cv2.imread('Files/Chess/002.png')
image3 = cv2.imread('Files/Chess/003.png')
image4 = cv2.imread('Files/Chess/004.png')
image5 = cv2.imread('Files/Chess/005.png')
image6 = cv2.imread('Files/Chess/006.png')
image7 = cv2.imread('Files/Chess/chess.png')

# %% [markdown]
# ## Image 1

# %%
# Make a copy of the image
image_copy = np.copy(image1)

# Change color to RGB (from BGR)
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

plt.imshow(image_copy)

# %%
# Convert to grayscale
gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)

t0 = time.time()
# Detect corners 
dst = cv2.cornerHarris(gray, 2, 5, 0.04)

# Dilate corner image to enhance corner points
dst = cv2.dilate(dst,None)

thresh = 0.1*dst.max()

# Create an image copy to draw corners on
corner_image = np.copy(image_copy)

# Iterate through all the corners and draw them on the image (if they pass the threshold)
for j in range(0, dst.shape[0]):
    for i in range(0, dst.shape[1]):
        if(dst[j,i] > thresh):
            # image, center pt, radius, color, thickness
            cv2.circle( corner_image, (i, j), 1, (0,255,0), 1)
print(f"time = {time.time() - t0}")
plt.figure(figsize=(25,10))
plt.imshow(corner_image)
# Out:
# time = 0.14708209037780762

# %% [markdown]
# ## Image (2)

# %%
# Make a copy of the image
image_copy = np.copy(image2)

# Change color to RGB (from BGR)
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

plt.imshow(image_copy)

# %%
# Convert to grayscale
gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)
t0 = time.time()
# Detect corners 
dst = cv2.cornerHarris(gray, 2, 5, 0.04)

# Dilate corner image to enhance corner points
dst = cv2.dilate(dst,None)

thresh = 0.07*dst.max()

# Create an image copy to draw corners on
corner_image = np.copy(image_copy)

# Iterate through all the corners and draw them on the image (if they pass the threshold)
for j in range(0, dst.shape[0]):
    for i in range(0, dst.shape[1]):
        if(dst[j,i] > thresh):
            # image, center pt, radius, color, thickness
            cv2.circle( corner_image, (i, j), 1, (0,255,0), 1)
print(f"time = {time.time() - t0}")            
plt.figure(figsize=(25,10))
plt.imshow(corner_image)
# Out:
# time = 0.14239168167114258

# %% [markdown]
# ## image(3)

# %%
#Make a copy of the image
image_copy = np.copy(image3)

# Change color to RGB (from BGR)
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

plt.imshow(image_copy)

# %%
# Convert to grayscale
gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)

t0 = time.time()
# Detect corners 
dst = cv2.cornerHarris(gray, 2, 3, 0.04)

# Dilate corner image to enhance corner points
dst = cv2.dilate(dst,None)

thresh = 0.081*dst.max()

# Create an image copy to draw corners on
corner_image = np.copy(image_copy)

# Iterate through all the corners and draw them on the image (if they pass the threshold)
for j in range(0, dst.shape[0]):
    for i in range(0, dst.shape[1]):
        if(dst[j,i] > thresh):
            # image, center pt, radius, color, thickness
            cv2.circle( corner_image, (i, j), 1, (0,255,0), 1)
print(f"time = {time.time() - t0}")
plt.figure(figsize=(25,10))
plt.imshow(corner_image)
# Out:
# time = 0.1521608829498291

# %% [markdown]
# ## image (4)

# %%
# Make a copy of the image
image_copy = np.copy(image4)

# Change color to RGB (from BGR)
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

plt.imshow(image_copy)

# %%
# Convert to grayscale
gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)

# Detect corners 
dst = cv2.cornerHarris(gray, 2, 3, 0.04)
t0 = time.time()
# Dilate corner image to enhance corner points
dst = cv2.dilate(dst,None)

thresh = 0.04*dst.max()

# Create an image copy to draw corners on
corner_image = np.copy(image_copy)

# Iterate through all the corners and draw them on the image (if they pass the threshold)
for j in range(0, dst.shape[0]):
    for i in range(0, dst.shape[1]):
        if(dst[j,i] > thresh):
            # image, center pt, radius, color, thickness
            cv2.circle( corner_image, (i, j), 1, (0,255,0), 1)
print(f"time = {time.time() - t0}")
plt.figure(figsize=(25,10))
plt.imshow(corner_image)
# Out:
# time = 0.14665675163269043

# %% [markdown]
# ## image (5)

# %%
# Make a copy of the image
image_copy = np.copy(image5)

# Change color to RGB (from BGR)
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

plt.imshow(image_copy)

# %%
# Convert to grayscale
gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)
t0 = time.time()
# Detect corners 
dst = cv2.cornerHarris(gray, 2, 3, 0.04)

# Dilate corner image to enhance corner points
dst = cv2.dilate(dst,None)

thresh = 0.05*dst.max()

# Create an image copy to draw corners on
corner_image = np.copy(image_copy)

# Iterate through all the corners and draw them on the image (if they pass the threshold)
for j in range(0, dst.shape[0]):
    for i in range(0, dst.shape[1]):
        if(dst[j,i] > thresh):
            # image, center pt, radius, color, thickness
            cv2.circle( corner_image, (i, j), 1, (0,255,0), 1)
            
print(f"time = {time.time() - t0}")
plt.figure(figsize=(25,10))
plt.imshow(corner_image)
# Out:
# time = 0.14281439781188965

# %% [markdown]
# ## image (6)

# %%
# Make a copy of the image
image_copy = np.copy(image6)

# Change color to RGB (from BGR)
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

plt.imshow(image_copy)

# %%
# Convert to grayscale
gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)
t0 = time.time()
# Detect corners 
dst = cv2.cornerHarris(gray, 2, 3, 0.04)

# Dilate corner image to enhance corner points
dst = cv2.dilate(dst,None)

thresh = 0.01*dst.max()

# Create an image copy to draw corners on
corner_image = np.copy(image_copy)

# Iterate through all the corners and draw them on the image (if they pass the threshold)
for j in range(0, dst.shape[0]):
    for i in range(0, dst.shape[1]):
        if(dst[j,i] > thresh):
            # image, center pt, radius, color, thickness
            cv2.circle( corner_image, (i, j), 1, (0,255,0), 1)
print(f"time = {time.time() - t0}")

plt.figure(figsize=(25,10))
plt.imshow(corner_image)
# Out:
# time = 0.14883041381835938

# %% [markdown]
# ## image (7)

# %%
# Make a copy of the image
image_copy = np.copy(image7)

# Change color to RGB (from BGR)
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

plt.imshow(image_copy)

# %%
# Convert to grayscale
gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)

t0 = time.time()
# Detect corners 
dst = cv2.cornerHarris(gray, 11, 11, 0.04)

# Dilate corner image to enhance corner points
dst = cv2.dilate(dst,None)

thresh = 0.01*dst.max()

# Create an image copy to draw corners on
corner_image = np.copy(image_copy)

# Iterate through all the corners and draw them on the image (if they pass the threshold)
for j in range(0, dst.shape[0]):
    for i in range(0, dst.shape[1]):
        if(dst[j,i] > thresh):
            # image, center pt, radius, colotime.time()r, thickness
            cv2.circle( corner_image, (i, j), 3, (255,0,0), 1)
print(f"time = {time.time() - t0}")

plt.figure(figsize=(25,10))
plt.imshow(corner_image)
# Out:
# time = 33.92006230354309
